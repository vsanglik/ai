# %% [markdown]
# <a href="https://colab.research.google.com/github/vsanglik/ai/blob/main/ML_02_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Refering to [Getting Started with LLMs
# ] https://www.youtube.com/watch?v=bB6BhgseYRA

# %% [markdown]
# #Vector

# %%
import numpy as np
vector = np.array([0.5,0.7,0.8])

# %% [markdown]
# #Embedding

# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer

# %%
from huggingface_hub import login

# %%
login()

# %%
model="huggyllama/llama-7b"
tokenizer=AutoTokenizer.from_pretrained(model, token="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")
# Out:
# tokenizer_config.json:   0%|          | 0.00/700 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %%
text="we are in airtribe session today"

# %%
tokenizer.encode(text)
# Out:
# [1, 591, 526, 297, 263, 2728, 374, 915, 4867, 9826]
